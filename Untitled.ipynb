# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.worldatlas.com/articles/what-are-the-most-popular-sports-in-the-world.html"

# %%
head = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36','Accept-Language':'en-US,en;q=0.5'})

# %%
web = requests.get(url,headers=head)

# %%
web
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en-US">\n    <head>\n        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n        <meta name="viewport" content="user-scalable=yes, initial-scale=1.0, width=device-width"/>\n        <meta name="robots" content="max-image-preview:large">\n        <meta http-equiv="Content-Security-Policy" content="block-all-mixed-content" />\n                    <link rel="canonical" href="https://www.worldatlas.com/articles/what-are-the-most-popular-sports-in-the-world.html"/>\n        \n                    <meta name="description" content="Discover the top 10 most popular sports in the world, their history, and what makes them so captivating \xe2\x80\x94 from soccer and cricket to basketball and golf.">\n        \n        \n        \n        <link rel="icon" href="/nwa_assets/img/site/favicon.png" type="image/x-icon">\n\n        <link rel="preload" href="https://www.worldatlas.com/nwa_assets/fonts/fontello/fontello.woff2?25012021" a
# ...

# %%
soup = BeautifulSoup(web.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="user-scalable=yes, initial-scale=1.0, width=device-width" name="viewport"/>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="block-all-mixed-content" http-equiv="Content-Security-Policy">
# <link href="https://www.worldatlas.com/articles/what-are-the-most-popular-sports-in-the-world.html" rel="canonical"/>
# <meta content="Discover the top 10 most popular sports in the world, their history, and what makes them so captivating — from soccer and cricket to basketball and golf." name="description"/>
# <link href="/nwa_assets/img/site/favicon.png" rel="icon" type="image/x-icon"/>
# <link as="font" crossorigin="" href="https://www.worldatlas.com/nwa_assets/fonts/fontello/fontello.woff2?25012021" rel="preload" type="font/woff2"/>
# <title>The Most Popular Sports In The World - WorldAtlas</title>
# ...

# %%
link = soup.find_all("div",attrs = {'class':'content_table'})

# %%
link[0].
# Out:
# <div class="content_table">
# <table><thead><tr><th>Rank</th>
# <th>Sport Name</th>
# <th>Amount of Fans</th>
# <th>Regions</th>
# </tr></thead><tbody><tr><td>1</td>
# <td><a href="#h_5767602536141694693417691">Football (Soccer)</a></td>
# <td>3.5 Billion</td>
# <td>Europe, Africa, Asia, America</td>
# </tr><tr><td>2</td>
# <td><a href="#h_2594068818471694693423178">Cricket</a></td>
# <td>2.5 Billion</td>
# <td>Asia, Australia, UK</td>
# </tr><tr><td>3</td>
# <td><a href="#h_99621067233771694693773798">Hockey</a></td>
# <td>2 Billion</td>
# <td>Europe, Africa, Asia, Australia</td>
# </tr><tr><td>4</td>
# <td><a href="#h_27789852812221694693430775">Tennis</a></td>
# <td>1 Billion</td>
# <td>Europe, Asia, America</td>
# </tr><tr><td>5</td>
# <td><a href="#h_87537890515011694693439255">Volleyball</a></td>
# <td>900 Million</td>
# <td>Europe, Australia, Asia, America</td>
# </tr><tr><td>6</td>
# <td><a href="#h_89166507518871694693445644">Table Tennis</a></td>
# <td>850 Million</td>
# ...

# %%
a = pd.read_html(str(link[0]))
a
# Out:
# C:\Users\delli\AppData\Local\Temp\ipykernel_5048\3832817716.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   a = pd.read_html(str(link[0]))
# [   Rank         Sport Name Amount of Fans                           Regions
#  0     1  Football (Soccer)    3.5 Billion     Europe, Africa, Asia, America
#  1     2            Cricket    2.5 Billion               Asia, Australia, UK
#  2     3             Hockey      2 Billion   Europe, Africa, Asia, Australia
#  3     4             Tennis      1 Billion             Europe, Asia, America
#  4     5         Volleyball    900 Million  Europe, Australia, Asia, America
#  5     6       Table Tennis    850 Million     Europe, Africa, Asia, America
#  6     7         Basketball    800 Million     America, Oceania, Middle East
#  7     8           Baseball    500 Million                    America, Japan
# ...

# %%
df=a[0]
df
# Out:
#    Rank         Sport Name Amount of Fans                           Regions
# 0     1  Football (Soccer)    3.5 Billion     Europe, Africa, Asia, America
# 1     2            Cricket    2.5 Billion               Asia, Australia, UK
# 2     3             Hockey      2 Billion   Europe, Africa, Asia, Australia
# 3     4             Tennis      1 Billion             Europe, Asia, America
# 4     5         Volleyball    900 Million  Europe, Australia, Asia, America
# 5     6       Table Tennis    850 Million     Europe, Africa, Asia, America
# 6     7         Basketball    800 Million     America, Oceania, Middle East
# 7     8           Baseball    500 Million                    America, Japan
# 8     9              Rugby    475 Million    Oceania, South Africa, England
# 9    10               Golf    450 Million          America, Oceania, Europe

# %%
df.to_excel("Sports.xlsx",index=False)
df
# Out:
#    Rank         Sport Name Amount of Fans                           Regions
# 0     1  Football (Soccer)    3.5 Billion     Europe, Africa, Asia, America
# 1     2            Cricket    2.5 Billion               Asia, Australia, UK
# 2     3             Hockey      2 Billion   Europe, Africa, Asia, Australia
# 3     4             Tennis      1 Billion             Europe, Asia, America
# 4     5         Volleyball    900 Million  Europe, Australia, Asia, America
# 5     6       Table Tennis    850 Million     Europe, Africa, Asia, America
# 6     7         Basketball    800 Million     America, Oceania, Middle East
# 7     8           Baseball    500 Million                    America, Japan
# 8     9              Rugby    475 Million    Oceania, South Africa, England
# 9    10               Golf    450 Million          America, Oceania, Europe

# %%
i = int(input("Enter the num."))
ans = i**(1/2)
print(ans)
# Out:
# Enter the num. 13
# 3.605551275463989

# %%
# Out:
# Enter the value> 12
